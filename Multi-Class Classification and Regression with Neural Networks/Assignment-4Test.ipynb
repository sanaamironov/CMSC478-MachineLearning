# %% [markdown]
# # CMSC478 Machine Learning - Spring 2020
#
# ## Instructor: Fereydoon Vafaei
#
# ## <font color="blue">Assignment-4: Multi-Class Classification and Regression with Neural Networks</font>

# %% [markdown]
# *  *

# %% [markdown]
# ## Overview and Learning Objectives

# %% [markdown]
# In Assignment-4, you're going to perform classification and regression using Neural Networks in Tensorflow and Keras.
#
# Pedagogically, this assignment will help you:
# - better understand how neural networks are built and applied on ML tasks - specifically classification and regression.
# - pratice NN implementation using Tensorflow 2 and Keras.

# %% [markdown]
# **Notice**: While some outputs are provided as reference, other outputs are NOT shared intentionally, and you should not share them or any solution code in Piazza.
#
# **Very Important Note:** You must run all cells and generate all outputs and plots. Notebooks with incomplete outputs will NOT be graded and will get ZERO credit!

# %% [markdown]
# ## Part I - Multi-Class Classification Using NN

# %% [markdown]
# First download the [data](https://github.com/fereydoonvafaei/CMSC478-Spring2020/blob/master/Assignment-4/video-games.csv). This is the same video games dataset you used in Assignment-2. You can read the descriptions of the data [here](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings). You are going to do multi-class classification on **Rating** as you did in A2.

# %% [markdown]
# ## <font color="red"> Required Coding

# %%
# Import necessary Python modules as well as Tensorflow and Keras
import tensorflow as tf
from tensorflow import keras
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
print("tf Version: ", tf.__version__)
print("Eager Execution mode: ", tf.executing_eagerly())
# Out:
# tf Version:  2.1.0
# Eager Execution mode:  True

# %% [markdown]
# > Load the data and do all the required preprocessing steps that you did in Assignment-2 for classification on "Rating".

# %%
# Load the data as a dataframe using pandas
game_data = pd.read_csv('video-games.csv')


print(game_data.shape)
game_data.head()
# Out:
# (16719, 16)
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# > Notice that preprocessing in A4, while extremely important to get the correct results moving forward, has no credit on its own because it's the same as A2.

# %% [markdown]
# ### Preprocessing

# %%
# Drop NAs

game_data = game_data.dropna()
print(game_data.shape)
game_data.head()

game_data.isna().sum()
# Out:
# (6825, 16)
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
# Drop "Name" column as it does not provide any useful info
game_data=game_data.drop(['Name'], axis=1)

print(game_data.shape)
game_data.head()
# Out:
# (6825, 15)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0         8.45         82.53          76.0          51.0          8
# 2         3.29         35.52          82.0          73.0        8.3
# 3         2.95         32.77          80.0          73.0          8
# 6         2.88         29.80          89.0          65.0        8.5
# 7         2.84         28.92          58.0          41.0        6.6
#
#    User_Count Developer Rating
# 0       322.0  Nintendo      E
# 2       709.0  Nintendo      E
# 3       192.0  Nintendo      E
# 6       431.0  Nintendo      E
# 7       129.0  Nintendo      E

# %%
# Drop "Global_Sales" column as it is redundant feature - it's just sum of regional and other sales
game_data=game_data.drop(['Global_Sales'], axis=1)

print(game_data.shape)
game_data.head()
# Out:
# (6825, 14)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer  \
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo
#
#   Rating
# 0      E
# 2      E
# 3      E
# 6      E
# 7      E

# %%
# Get feature vector X (all columns but "Rating") and target label y as "Rating"
X = game_data.drop(['Rating'], axis=1)
y = game_data['Rating']

# %%
# Print X shape and head
print(X.shape)
X.head()
# Out:
# (6825, 13)
#   Platform  Year_of_Release     Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     41.36     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     15.68     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     15.61     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo     11.28      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo     13.96      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo

# %%
# Using pandas.get_dummies() create dummy variables for categorical features
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# Using pandas.get_dummies() create dummy variables for categorical features (needs 1 line of code only)
X = pd.get_dummies(X)

print(X.shape)

X.head()
# Out:
# (6825, 1677)
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score  \
# 0           2006.0     41.36     28.96      3.77         8.45          76.0
# 2           2008.0     15.68     12.76      3.79         3.29          82.0
# 3           2009.0     15.61     10.93      3.28         2.95          80.0
# 6           2006.0     11.28      9.14      6.50         2.88          89.0
# 7           2006.0     13.96      9.18      2.93         2.84          58.0
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  ...  \
# 0          51.0       322.0             0            0  ...
# 2          73.0       709.0             0            0  ...
# 3          73.0       192.0             0            0  ...
# 6          65.0       431.0             0            0  ...
# 7          41.0       129.0             0            0  ...
#
#    Developer_h.a.n.d. Inc.  Developer_iNiS  Developer_id Software  \
# 0                        0               0                      0
# 2                        0               0                      0
# 3                        0               0                      0
# 6                        0               0                      0
# 7                        0               0                      0
#
#    Developer_id Software, Nerve Software  \
# 0                                      0
# 2                                      0
# 3                                      0
# 6                                      0
# 7                                      0
#
#    Developer_id Software, Raven Software  Developer_n-Space  \
# 0                                      0                  0
# 2                                      0                  0
# 3                                      0                  0
# 6                                      0                  0
# 7                                      0                  0
#
#    Developer_neo Software  Developer_odenis studio  Developer_syn Sophia  \
# 0                       0                        0                     0
# 2                       0                        0                     0
# 3                       0                        0                     0
# 6                       0                        0                     0
# 7                       0                        0                     0
#
#    Developer_zSlide
# 0                 0
# 2                 0
# 3                 0
# 6                 0
# 7                 0
#
# [5 rows x 1677 columns]

# %%
# Print y shape and head and its unique values
print(y.shape)
print(y.unique())
y.head()
# Out:
# (6825,)
# ['E' 'M' 'T' 'E10+' 'AO' 'K-A' 'RP']
# 0    E
# 2    E
# 3    E
# 6    E
# 7    E
# Name: Rating, dtype: object

# %% [markdown]
# > <b>Note:</b> The output of the following cells is provided to you for your reference. All the following cells depend on the correctness of your preprocessing steps and can be verified by these outputs.

# %%
# Convert categorical class labels to numerical
# Convert categorical class labels to numerical
y = y.map(lambda x: {'E' :0, 'E10+' :1, 'T' :2, 'M' :3, 'AO' :4, 'K-A' :5, 'RP' :6}.get(x))

print(y.unique())
print(y.shape)
print(type(y))
y.head()
# Out:
# [0 3 2 1 4 5 6]
# (6825,)
# <class 'pandas.core.series.Series'>
# 0    0
# 2    0
# 3    0
# 6    0
# 7    0
# Name: Rating, dtype: int64

# %%
# Normalize X using mean() and std()  NOTE: The output is provided for your reference.
Xmeans = X.mean()
Xstds = np.std(X)


# Use the means and standard deviations to standardize X and T
X = (X-Xmeans)/Xstds

print(X.shape)
X.head()
# Out:
# (6825, 1677)
#    Year_of_Release   NA_Sales   EU_Sales   JP_Sales  Other_Sales  \
# 0        -0.341201  42.349741  41.793631  12.887711    31.007176
# 2         0.133752  15.802014  18.222438  12.957265    11.885525
# 3         0.371229  15.729649  15.559767  11.183651    10.625572
# 6        -0.341201  11.253338  12.955296  22.381762    10.366169
# 7        -0.341201  14.023895  13.013496   9.966465    10.217939
#
#    Critic_Score  Critic_Count  User_Count  Platform_3DS  Platform_DC  ...  \
# 0      0.413044      1.148059    0.250734     -0.152441    -0.045338  ...
# 2      0.845709      2.292536    0.909586     -0.152441    -0.045338  ...
# 3      0.701487      2.292536    0.029415     -0.152441    -0.045338  ...
# 6      1.350484      1.876363    0.436302     -0.152441    -0.045338  ...
# 7     -0.884950      0.627843   -0.077840     -0.152441    -0.045338  ...
#
#    Developer_h.a.n.d. Inc.  Developer_iNiS  Developer_id Software  \
# 0                -0.029663       -0.024216              -0.034257
# 2                -0.029663       -0.024216              -0.034257
# 3                -0.029663       -0.024216              -0.034257
# 6                -0.029663       -0.024216              -0.034257
# 7                -0.029663       -0.024216              -0.034257
#
#    Developer_id Software, Nerve Software  \
# 0                              -0.012105
# 2                              -0.012105
# 3                              -0.012105
# 6                              -0.012105
# 7                              -0.012105
#
#    Developer_id Software, Raven Software  Developer_n-Space  \
# 0                               -0.02097          -0.043685
# 2                               -0.02097          -0.043685
# 3                               -0.02097          -0.043685
# 6                               -0.02097          -0.043685
# 7                               -0.02097          -0.043685
#
#    Developer_neo Software  Developer_odenis studio  Developer_syn Sophia  \
# 0               -0.012105                -0.012105             -0.017121
# 2               -0.012105                -0.012105             -0.017121
# 3               -0.012105                -0.012105             -0.017121
# 6               -0.012105                -0.012105             -0.017121
# 7               -0.012105                -0.012105             -0.017121
#
#    Developer_zSlide
# 0         -0.012105
# 2         -0.012105
# 3         -0.012105
# 6         -0.012105
# 7         -0.012105
#
# [5 rows x 1677 columns]

# %%
# Split the data to train and test with ratio of 80/20 for train/test respectively
from sklearn.model_selection import train_test_split
# Split the data to training set and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5460, 1677)
# (5460,)
# (1365, 1677)
# (1365,)

# %% [markdown]
# > Now, you should put the data into tensors. Be aware though that there are other ways to prepare the data in tensorflow.

# %%
# Batch train and test data
train_tensor = tf.data.Dataset.from_tensor_slices((X_train.values, y_train.values))
test_tensor = tf.data.Dataset.from_tensor_slices((X_test.values, y_test.values))
train_batch = train_tensor.shuffle(len(X_train)).batch(10)
test_batch = test_tensor.shuffle(len(X_test)).batch(10)

# %%
type(train_tensor)
# Out:
# tensorflow.python.data.ops.dataset_ops.TensorSliceDataset

# %%
train_tensor.element_spec
# Out:
# (TensorSpec(shape=(1677,), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %% [markdown]
# ### Building the NN for Multi-Class Classification

# %% [markdown]
# > You can begin with a simple neural network with a couple of hidden layers, and increase number of hidden layers and neurons as needed. You may also use callback and early stopping to find the optimal number of epochs, but it's possible to obtain the minimum required accuracy (0.70) with 20 epochs only.
#
# > **Hint**: During training, you should see a clear trend of descending loss and increasing accuracy epoch after epoch; otherwise, your model has not been developed properly.
#
# > **Very Important Note**: All your cells should be run and show outputs and/or plots!

# %%
# Build a sequential NN with appropriate layers for multi-class classification
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train

# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Multi-class Classification

# nn_clf = tf.keras.Sequential([
#      tf.keras.layers.Dense(800, input_dim=(1677), activation='relu'),
#     tf.keras.layers.Dense(800, activation='relu'),
#     tf.keras.layers.Dense(800, activation='relu'),
#     tf.keras.layers.Dense(800, activation='relu'),
#     tf.keras.layers.Dense(800, activation='relu'),
#     tf.keras.layers.Dense(7, activation='softmax')
#     ]) 



model = keras.Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='zero'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='zero'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='zero'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='zero'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10))
model.add(Dropout(0.2))

optimizer = SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=optimizer, loss='mae', metrics=['mae'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-df27c6e7771f> in <module>
#      19
#      20 model = keras.Sequential()
# ---> 21 model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
#      22 model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
#      23 model.add(MaxPooling2D((2, 2)))
#
# NameError: name 'Conv2D' is not defined

# %%
nn_clf.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 700)               1174600
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 4,614,407
# Trainable params: 4,614,407
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile nn_clf with loss='sparse_categorical_crossentropy' and metrics=['sparse_categorical_accuracy']
# Hint1: One of the hyperparameters you can change is the optimizer (Adam, RMSprop, SGD, ...)
# Hint2: The other impactful hyperparameter is learning_rate
optimizer = tf.keras.optimizers.Adam()
nn_clf.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# > To train the model, you use `fit()` method, and since you've created `train_batch`, you don't need to pass `y_train` as it's already included in the batch.

# %%
# Fit the network on train_batch with 20 epochs (you may train with more epochs or use callback if needed)
nn_clf_history = nn_clf.fit(train_batch, epochs=20)
# Out:
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.2290 - sparse_categorical_accuracy: 0.4462
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.9173 - sparse_categorical_accuracy: 0.5872
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.7107 - sparse_categorical_accuracy: 0.7275
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.6179 - sparse_categorical_accuracy: 0.7744
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.5094 - sparse_categorical_accuracy: 0.8161
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.4509 - sparse_categorical_accuracy: 0.8392: 1s - loss: 0.4501 - sparse_categ
# Epoch 7/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.4055 - sparse_categorical_accuracy: 0.8518
# Epoch 8/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.3428 - sparse_categorical_accuracy: 0.8802
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.3088 - sparse_categorical_accuracy: 0.8916
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2677 - sparse_categorical_accuracy: 0.9081
# Epoch 11/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2367 - sparse_categorical_accuracy: 0.9227
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2513 - sparse_categorical_accuracy: 0.9209
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9383
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2273 - sparse_categorical_accuracy: 0.9324
# Epoch 15/20
# 546/546 [==============================] - 10s 17ms/step - loss: 0.4481 - sparse_categorical_accuracy: 0.9200
# Epoch 16/20
# 546/546 [==============================] - 10s 17ms/step - loss: 0.2101 - sparse_categorical_accuracy: 0.9421
# Epoch 17/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1719 - sparse_categorical_accuracy: 0.9542
# Epoch 18/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1200 - sparse_categorical_accuracy: 0.9641
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1343 - sparse_categorical_accuracy: 0.9658
# Epoch 20/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0946 - sparse_categorical_accuracy: 0.9720

# %%
pd.DataFrame(nn_clf_history.history).plot(figsize=(10, 5))
plt.grid(True)

# Set the xticks - label locations
plt.xticks(np.arange(0, 20, step=2))  

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 1)
# Out:
# (0, 1)

# %% [markdown]
# > To evaluate the model, you use `evaluate()` method.
#
# > <font color='red'>**Minimum Accuracy Requirement**</font>: Your accuracy on `test_batch` must be at least **0.70**. Otherwise, your notebook will get NO CREDIT for this part, so you must fine-tune your `nn_clf` accordingly.

# %%
# Evaluate the model on test_batch - no need to pass y_test because it's included in test_batch
cross_entropy_loss, accuracy = nn_clf.evaluate(test_batch)
# Out:
# 137/137 [==============================] - 1s 4ms/step - loss: 9.3210 - sparse_categorical_accuracy: 0.7004

# %%
# Minimum Required Accuracy: 0.70
round(accuracy, 2)
# Out:
# 0.7

# %%
y_pred = nn_clf.predict_classes(X_test)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
y_pred
# Out:
# array([5, 4, 5, ..., 4, 5, 5])

# %% [markdown]
# > Get a [classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html).

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       406
#            1       0.00      0.00      0.00       182
#            2       0.00      0.00      0.00       466
#            3       0.33      0.00      0.01       310
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#
#     accuracy                           0.00      1365
#    macro avg       0.05      0.00      0.00      1365
# weighted avg       0.08      0.00      0.00      1365

# %% [markdown]
# > Next, you're going to fine-tune your learning-rate specifically. To do so and to avoid repeating the code, let's write a function.

# %%
def build_model():
    nn_clf = tf.keras.Sequential([
    tf.keras.layers.Dense(700, input_dim=(1677), activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(700, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
    ])  
    return nn_clf

# %% [markdown]
# > The learning rate range that you're going to investigate is between 0.001 and 0.1 with an increment step of 0.001. Use the optimizer of your choice that performed the best in your fine-tuning, and don't change it in the `for` loop.
#
# > It's possible to try different learning rate scheduling policies, including those policies with an exponential decay rate, but you narrow down your investigation on this specific range for this part of the assignment.
#
# > Running this cell may take a few minutes!

# %%
accuracies = []
learning_rates = np.arange(0.001, 0.011, 0.001)

''' Write a for loop that iterates over learning_rate
    In each iteration:
        build a new model by calling build_model(),
        compile with the optimizer of your choice and the current learning_rate,
        train on train_batch with 20 epochs,
        evaluate on test_batch and get the accuracy,
        append accuracy to accuracies
'''
for lr in learning_rates: #lr is current learning rate
    print("lr = ",lr)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    nn_clf.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    nn_clf_history = nn_clf.fit(train_batch, epochs=20)
    cross_entropy_loss, accuracy = nn_clf.evaluate(test_batch)
    accuracies.append(accuracy)
# Out:
# lr =  0.001
# Epoch 1/20
# 546/546 [==============================] - 11s 19ms/step - loss: 0.1350 - sparse_categorical_accuracy: 0.9711
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1473 - sparse_categorical_accuracy: 0.9703
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9683
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9755
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2208 - sparse_categorical_accuracy: 0.9674
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2498 - sparse_categorical_accuracy: 0.9564
# Epoch 7/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2983 - sparse_categorical_accuracy: 0.9522
# Epoch 8/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1754 - sparse_categorical_accuracy: 0.9689
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2462 - sparse_categorical_accuracy: 0.9672
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2281 - sparse_categorical_accuracy: 0.9703
# Epoch 11/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1318 - sparse_categorical_accuracy: 0.9786
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.1367 - sparse_categorical_accuracy: 0.9725
# Epoch 13/20
# 546/546 [==============================] - 10s 19ms/step - loss: 0.2646 - sparse_categorical_accuracy: 0.9797
# Epoch 14/20
# 546/546 [==============================] - 11s 20ms/step - loss: 0.2202 - sparse_categorical_accuracy: 0.9692
# Epoch 15/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1449 - sparse_categorical_accuracy: 0.9714
# Epoch 16/20
# 546/546 [==============================] - 10s 19ms/step - loss: 0.1299 - sparse_categorical_accuracy: 0.9775
# Epoch 17/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9828
# Epoch 18/20
# 546/546 [==============================] - 10s 19ms/step - loss: 0.0745 - sparse_categorical_accuracy: 0.9830
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1090 - sparse_categorical_accuracy: 0.9826
# Epoch 20/20
# 546/546 [==============================] - 10s 19ms/step - loss: 0.1444 - sparse_categorical_accuracy: 0.9799
# 137/137 [==============================] - 1s 4ms/step - loss: 16.5428 - sparse_categorical_accuracy: 0.7136
# lr =  0.002
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.0251 - sparse_categorical_accuracy: 0.9359
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.6908 - sparse_categorical_accuracy: 0.8914
# Epoch 3/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.5556 - sparse_categorical_accuracy: 0.9189
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.2779 - sparse_categorical_accuracy: 0.9458
# Epoch 5/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.1942 - sparse_categorical_accuracy: 0.9588
# Epoch 6/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.5848 - sparse_categorical_accuracy: 0.8423
# Epoch 7/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.7216
# Epoch 8/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.0628 - sparse_categorical_accuracy: 0.5484
# Epoch 9/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3646 - sparse_categorical_accuracy: 0.6011
# Epoch 10/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.0689 - sparse_categorical_accuracy: 0.5782
# Epoch 11/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.0001 - sparse_categorical_accuracy: 0.5797
# Epoch 12/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.2711 - sparse_categorical_accuracy: 0.5271
# Epoch 13/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.4453 - sparse_categorical_accuracy: 0.3408
# Epoch 14/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3326 - sparse_categorical_accuracy: 0.3423
# Epoch 15/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3317 - sparse_categorical_accuracy: 0.3386
# Epoch 16/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3287 - sparse_categorical_accuracy: 0.3496
# Epoch 17/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3298 - sparse_categorical_accuracy: 0.3463
# Epoch 18/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3294 - sparse_categorical_accuracy: 0.3449
# Epoch 19/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3286 - sparse_categorical_accuracy: 0.3408
# Epoch 20/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3311 - sparse_categorical_accuracy: 0.3405
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3594 - sparse_categorical_accuracy: 0.3670
# lr =  0.003
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.6524 - sparse_categorical_accuracy: 0.4223
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 2.4500 - sparse_categorical_accuracy: 0.3652
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3425 - sparse_categorical_accuracy: 0.3275
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3413 - sparse_categorical_accuracy: 0.3321
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3414 - sparse_categorical_accuracy: 0.3366
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3417 - sparse_categorical_accuracy: 0.3337
# Epoch 7/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3420 - sparse_categorical_accuracy: 0.3313
# Epoch 8/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3430 - sparse_categorical_accuracy: 0.3322
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3412 - sparse_categorical_accuracy: 0.3364
# Epoch 10/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3405 - sparse_categorical_accuracy: 0.3432
# Epoch 11/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3407 - sparse_categorical_accuracy: 0.3317
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3399 - sparse_categorical_accuracy: 0.3353
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3416 - sparse_categorical_accuracy: 0.3377
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3391 - sparse_categorical_accuracy: 0.3353
# Epoch 15/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3406 - sparse_categorical_accuracy: 0.3277
# Epoch 16/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3396 - sparse_categorical_accuracy: 0.3375
# Epoch 17/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3386 - sparse_categorical_accuracy: 0.3355
# Epoch 18/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3390 - sparse_categorical_accuracy: 0.3361
# Epoch 19/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3372 - sparse_categorical_accuracy: 0.3339
# Epoch 20/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3380 - sparse_categorical_accuracy: 0.3416
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3526 - sparse_categorical_accuracy: 0.3634
# lr =  0.004
# Epoch 1/20
# 546/546 [==============================] - 11s 19ms/step - loss: 1.3407 - sparse_categorical_accuracy: 0.3397
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3385 - sparse_categorical_accuracy: 0.3405
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3386 - sparse_categorical_accuracy: 0.3397
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3371 - sparse_categorical_accuracy: 0.3397
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3382 - sparse_categorical_accuracy: 0.3383
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3379 - sparse_categorical_accuracy: 0.3375
# Epoch 7/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3374 - sparse_categorical_accuracy: 0.3407
# Epoch 8/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3371 - sparse_categorical_accuracy: 0.3385
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3378 - sparse_categorical_accuracy: 0.3419
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3427
# Epoch 11/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3373 - sparse_categorical_accuracy: 0.3427
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.3355
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3372 - sparse_categorical_accuracy: 0.3427
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3372 - sparse_categorical_accuracy: 0.3423
# Epoch 15/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3374 - sparse_categorical_accuracy: 0.3421
# Epoch 16/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3358 - sparse_categorical_accuracy: 0.3397
# Epoch 17/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3378 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3370 - sparse_categorical_accuracy: 0.3401
# Epoch 19/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3445
# Epoch 20/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3370 - sparse_categorical_accuracy: 0.3423
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3375 - sparse_categorical_accuracy: 0.3634
# lr =  0.005
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3373 - sparse_categorical_accuracy: 0.3427
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3425
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3436
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3379
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3441
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3414
# Epoch 7/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3414
# Epoch 8/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.3445
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3419
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 11/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3445
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.3445
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3360 - sparse_categorical_accuracy: 0.3430
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3432
# Epoch 15/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3368 - sparse_categorical_accuracy: 0.3438
# Epoch 16/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3445
# Epoch 17/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 20/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3429
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3315 - sparse_categorical_accuracy: 0.3634
# lr =  0.006
# Epoch 1/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3371 - sparse_categorical_accuracy: 0.3416
# Epoch 2/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3445
# Epoch 3/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3445
# Epoch 4/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 5/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3416
# Epoch 6/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3429
# Epoch 7/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3423
# Epoch 8/20
# 546/546 [==============================] - 9s 16ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3412
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3399
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3445
# Epoch 11/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3354 - sparse_categorical_accuracy: 0.3445
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3445
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3445
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3360 - sparse_categorical_accuracy: 0.3445
# Epoch 15/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3356 - sparse_categorical_accuracy: 0.3434
# Epoch 16/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3418
# Epoch 17/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3430
# Epoch 18/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 19/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3445
# Epoch 20/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3445
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3351 - sparse_categorical_accuracy: 0.3634
# lr =  0.007
# Epoch 1/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3418
# Epoch 2/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 3/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3360 - sparse_categorical_accuracy: 0.3445
# Epoch 4/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3445
# Epoch 5/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3397
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3440
# Epoch 7/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3354 - sparse_categorical_accuracy: 0.3445
# Epoch 8/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3354 - sparse_categorical_accuracy: 0.3445
# Epoch 9/20
# 546/546 [==============================] - 11s 19ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3425
# Epoch 10/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3351 - sparse_categorical_accuracy: 0.3399
# Epoch 11/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3421
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3445
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3423
# Epoch 14/20
# 546/546 [==============================] - 11s 19ms/step - loss: 1.3356 - sparse_categorical_accuracy: 0.3445
# Epoch 15/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 16/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 17/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3414
# Epoch 19/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3358 - sparse_categorical_accuracy: 0.3449
# Epoch 20/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3352 - sparse_categorical_accuracy: 0.3441
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3355 - sparse_categorical_accuracy: 0.3634
# lr =  0.008
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3430
# Epoch 2/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3358 - sparse_categorical_accuracy: 0.3434
# Epoch 3/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3430
# Epoch 4/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3408
# Epoch 5/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3416
# Epoch 6/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 7/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3425
# Epoch 8/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 9/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3358 - sparse_categorical_accuracy: 0.3445
# Epoch 10/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3360 - sparse_categorical_accuracy: 0.3392
# Epoch 11/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3356 - sparse_categorical_accuracy: 0.3416
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3434
# Epoch 14/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3410
# Epoch 15/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3354 - sparse_categorical_accuracy: 0.3416
# Epoch 16/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3421
# Epoch 17/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3352 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3436
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3427
# Epoch 20/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# 137/137 [==============================] - 1s 5ms/step - loss: 1.3403 - sparse_categorical_accuracy: 0.3634
# lr =  0.009000000000000001
# Epoch 1/20
# 546/546 [==============================] - 11s 19ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.3396
# Epoch 2/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3441
# Epoch 3/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3438
# Epoch 4/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3445
# Epoch 5/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3445
# Epoch 6/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3445
# Epoch 7/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3379
# Epoch 8/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3445
# Epoch 9/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 10/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3445
# Epoch 11/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3445
# Epoch 12/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3403
# Epoch 13/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3388
# Epoch 14/20
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3418
# Epoch 15/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3445
# Epoch 16/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3416
# Epoch 17/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 20/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3359 - sparse_categorical_accuracy: 0.3416
# 137/137 [==============================] - 1s 4ms/step - loss: 1.3323 - sparse_categorical_accuracy: 0.3634
# lr =  0.010000000000000002
# Epoch 1/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3414
# Epoch 2/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3372 - sparse_categorical_accuracy: 0.3427
# Epoch 3/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 4/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3412
# Epoch 5/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3364 - sparse_categorical_accuracy: 0.3445
# Epoch 6/20
# 546/546 [==============================] - 10s 19ms/step - loss: 1.3368 - sparse_categorical_accuracy: 0.3390
# Epoch 7/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3369 - sparse_categorical_accuracy: 0.3445
# Epoch 8/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3445
# Epoch 9/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3429
# Epoch 10/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3425
# Epoch 11/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3356 - sparse_categorical_accuracy: 0.3421
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3362 - sparse_categorical_accuracy: 0.3410
# Epoch 13/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3363 - sparse_categorical_accuracy: 0.3445
# Epoch 14/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3367 - sparse_categorical_accuracy: 0.3410
# Epoch 15/20
# 546/546 [==============================] - 10s 17ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3421
# Epoch 16/20
# 546/546 [==============================] - 10s 18ms/step - loss: 1.3365 - sparse_categorical_accuracy: 0.3394
# Epoch 17/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3366 - sparse_categorical_accuracy: 0.3445
# Epoch 18/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3355 - sparse_categorical_accuracy: 0.3419
# Epoch 19/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3445
# Epoch 20/20
# 546/546 [==============================] - 11s 20ms/step - loss: 1.3357 - sparse_categorical_accuracy: 0.3390
# 137/137 [==============================] - 1s 5ms/step - loss: 1.3333 - sparse_categorical_accuracy: 0.3634

# %%
plt.title('Impact of Learning Rate on Accuracy')

#x = np.array(lr)
#y = np.array(accuracies)
#plt.plot([0, 1], [0, 1],'r')
plt.xlim([0.001, 0.011])
plt.ylim([.36, .72])
plt.plot(learning_rates, accuracies,'r-')
plt.ylabel('accuracies')
plt.xlabel('learning_rates')
#plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Part I - Questions

# %% [markdown]
# ANSWER THE FOLLOWING QUESTIONS HERE:
#
# **Q1 [5 points]** - According to your learning rate fine-tuning plot, what is a good value for learning rate?
#
# .001
#
#
# **Q2 [5 points]** - If you change the batch size in `train_batch` and `test_batch`:
#
# (a - 2 points) would it increase or decrease the speed of training? Also, would it increase or decrease the accuracy? YOU MUST DO EXPERIMENTS and report whether training speed and accuracy increase or decrease by changing batch size.
#
# The speed of training decreases with increased train batch and test batch, but during experiments I noticed that the accuracy decreased.
#
# (b - 3 points) Explain why those observations on training speed and accuracy happen.
#
# Larger batch sizes have lower accuracy due to the model not being able to generalize as well as a smaller sized batch.
#
# **Q3 [5 points]** - Name five learning rate scheduling policies known as **learning schedules** (you may consult with the textbook), and explain each briefly in no more than two sentences.
# Power, Exponential, Piecewise constant, Performance, 1cycle. Power scheduling requires tuning n0 (ininital learning rate) and s (steps), learning rate drops at each step and goes down to n0/1, n0/2...and on, exponential scheduling slashes by a factor of 10 at every s steps, piecewise constant scheduling using constant learning rate and and smaller learning rate for every other epochs. Performance scheduling measures error every N steps then reduces learning rate by a factor when the error stops dropping and lastly 1cycle scheduling incrases the larning rate and then grows linearly halfway through training then decreases learning rate linearly halfway trhough training.

# %% [markdown]
# ## Part II - Regression Using NNs

# %% [markdown]
# In Part II, you're going to perform regression using NNs.

# %% [markdown]
# You're going to predict `NA_Sales` based on other sales in the world. It is possible to frame the regression problem with other values as target, but this is how you're going to do regression practice for Part II. Notice that you should already drop `Global_Sales` from your game_data.

# %% [markdown]
# ## <font color="red"> Required Coding

# %%
# Get feature vector X_reg (all columns but "NA_Sales") and target label y_reg as "NA_Sales"
#popped_col = game_data.pop("NA_Sales")

X_reg = game_data.drop(['NA_Sales'],axis=1)
y_reg = game_data['NA_Sales']

# %%
# Print X_reg shape and head
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 13)
#   Platform  Year_of_Release     Genre Publisher  EU_Sales  JP_Sales  \
# 0      Wii           2006.0    Sports  Nintendo     28.96      3.77
# 2      Wii           2008.0    Racing  Nintendo     12.76      3.79
# 3      Wii           2009.0    Sports  Nintendo     10.93      3.28
# 6       DS           2006.0  Platform  Nintendo      9.14      6.50
# 7      Wii           2006.0      Misc  Nintendo      9.18      2.93
#
#    Other_Sales  Critic_Score  Critic_Count User_Score  User_Count Developer  \
# 0         8.45          76.0          51.0          8       322.0  Nintendo
# 2         3.29          82.0          73.0        8.3       709.0  Nintendo
# 3         2.95          80.0          73.0          8       192.0  Nintendo
# 6         2.88          89.0          65.0        8.5       431.0  Nintendo
# 7         2.84          58.0          41.0        6.6       129.0  Nintendo
#
#   Rating
# 0      E
# 2      E
# 3      E
# 6      E
# 7      E

# %%
# Using pandas.get_dummies() create dummy variables for categorical features

X_reg = pd.get_dummies(X_reg)
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 1683)
#    Year_of_Release  EU_Sales  JP_Sales  Other_Sales  Critic_Score  \
# 0           2006.0     28.96      3.77         8.45          76.0
# 2           2008.0     12.76      3.79         3.29          82.0
# 3           2009.0     10.93      3.28         2.95          80.0
# 6           2006.0      9.14      6.50         2.88          89.0
# 7           2006.0      9.18      2.93         2.84          58.0
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  Platform_DS  ...  \
# 0          51.0       322.0             0            0            0  ...
# 2          73.0       709.0             0            0            0  ...
# 3          73.0       192.0             0            0            0  ...
# 6          65.0       431.0             0            0            1  ...
# 7          41.0       129.0             0            0            0  ...
#
#    Developer_odenis studio  Developer_syn Sophia  Developer_zSlide  Rating_AO  \
# 0                        0                     0                 0          0
# 2                        0                     0                 0          0
# 3                        0                     0                 0          0
# 6                        0                     0                 0          0
# 7                        0                     0                 0          0
#
#    Rating_E  Rating_E10+  Rating_K-A  Rating_M  Rating_RP  Rating_T
# 0         1            0           0         0          0         0
# 2         1            0           0         0          0         0
# 3         1            0           0         0          0         0
# 6         1            0           0         0          0         0
# 7         1            0           0         0          0         0
#
# [5 rows x 1683 columns]

# %%
# Normalize X_reg using mean() and std()  NOTE: The output is provided for your reference.

X_reg = (X_reg - X_reg.mean())/X_reg.std()
print(X_reg.shape)
X_reg.head()
# Out:
# (6825, 1683)
#    Year_of_Release   EU_Sales   JP_Sales  Other_Sales  Critic_Score  \
# 0        -0.341176  41.790569  12.886767    31.004904      0.413014
# 2         0.133743  18.221103  12.956315    11.884655      0.845647
# 3         0.371202  15.558627  11.182831    10.624793      0.701436
# 6        -0.341176  12.954346  22.380122    10.365410      1.350385
# 7        -0.341176  13.012543   9.965734    10.217191     -0.884885
#
#    Critic_Count  User_Count  Platform_3DS  Platform_DC  Platform_DS  ...  \
# 0      1.147975    0.250716      -0.15243    -0.045334    -0.270063  ...
# 2      2.292368    0.909519      -0.15243    -0.045334    -0.270063  ...
# 3      2.292368    0.029412      -0.15243    -0.045334    -0.270063  ...
# 6      1.876225    0.436270      -0.15243    -0.045334     3.702302  ...
# 7      0.627797   -0.077835      -0.15243    -0.045334    -0.270063  ...
#
#    Developer_odenis studio  Developer_syn Sophia  Developer_zSlide  Rating_AO  \
# 0                -0.012105              -0.01712         -0.012105  -0.012105
# 2                -0.012105              -0.01712         -0.012105  -0.012105
# 3                -0.012105              -0.01712         -0.012105  -0.012105
# 6                -0.012105              -0.01712         -0.012105  -0.012105
# 7                -0.012105              -0.01712         -0.012105  -0.012105
#
#    Rating_E  Rating_E10+  Rating_K-A  Rating_M  Rating_RP  Rating_T
# 0  1.509226    -0.397162   -0.012105 -0.515485  -0.012105 -0.730971
# 2  1.509226    -0.397162   -0.012105 -0.515485  -0.012105 -0.730971
# 3  1.509226    -0.397162   -0.012105 -0.515485  -0.012105 -0.730971
# 6  1.509226    -0.397162   -0.012105 -0.515485  -0.012105 -0.730971
# 7  1.509226    -0.397162   -0.012105 -0.515485  -0.012105 -0.730971
#
# [5 rows x 1683 columns]

# %%
# Split the data to train and test with ratio of 80/20 for train/test respectively
from sklearn.model_selection import train_test_split
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size=0.2)

print(X_reg_train.shape)
print(y_reg_train.shape)
print(X_reg_test.shape)
print(y_reg_test.shape)
# Out:
# (5460, 1683)
# (5460,)
# (1365, 1683)
# (1365,)

# %%
# Batch the data
train_tensor_reg = tf.data.Dataset.from_tensor_slices((X_reg_train.values, y_reg_train.values))
test_tensor_reg = tf.data.Dataset.from_tensor_slices((X_reg_test.values, y_reg_test.values))
train_batch_reg = train_tensor_reg.shuffle(len(X_reg_train)).batch(10)
test_batch_reg = test_tensor_reg.shuffle(len(X_reg_test)).batch(10)

# %%
train_tensor_reg.element_spec
# Out:
# (TensorSpec(shape=(1683,), dtype=tf.float64, name=None),
#  TensorSpec(shape=(), dtype=tf.float64, name=None))

# %% [markdown]
# ### Building NN for Regression

# %%
# Build a sequential NN with appropriate layers for regression
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train_reg
# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Regression

nn_reg = tf.keras.Sequential([
    # Add layers accordingly
    tf.keras.layers.Dense(800, activation = 'relu', input_dim=1683),
    tf.keras.layers.Dense(800, activation = 'relu'),
    tf.keras.layers.Dense(800, activation = 'relu'),    
    tf.keras.layers.Dense(800, activation = 'relu'),
    tf.keras.layers.Dense(1)
    ])

# %%
nn_reg.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 800)               1347200
# _________________________________________________________________
# dense_15 (Dense)             (None, 800)               640800
# _________________________________________________________________
# dense_16 (Dense)             (None, 800)               640800
# _________________________________________________________________
# dense_17 (Dense)             (None, 800)               640800
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 801
# =================================================================
# Total params: 3,270,401
# Trainable params: 3,270,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile nn_reg with appropriate loss and metric

# Hint1: You need to choose the loss and metric for regression
# Hint2: For this regression task, loss and metrics might be the same

nn_reg.compile(loss= 'mean_squared_error', metrics=['mse'])

# %%
# Fit the network on train_batch_reg with 20 epochs
EPOCHS = 20

nn_reg_history = nn_reg.fit(train_batch_reg, epochs=EPOCHS)
# Out:
# Epoch 1/20
# 546/546 [==============================] - 20s 36ms/step - loss: 0.0881 - mse: 0.0881
# Epoch 2/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0609 - mse: 0.0608
# Epoch 3/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0564 - mse: 0.0563
# Epoch 4/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0462 - mse: 0.0461
# Epoch 5/20
# 546/546 [==============================] - 17s 32ms/step - loss: 0.0436 - mse: 0.0436
# Epoch 6/20
# 546/546 [==============================] - 18s 32ms/step - loss: 0.0476 - mse: 0.0476
# Epoch 7/20
# 546/546 [==============================] - 17s 32ms/step - loss: 0.0249 - mse: 0.0248
# Epoch 8/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0500 - mse: 0.0499
# Epoch 9/20
# 546/546 [==============================] - 18s 32ms/step - loss: 0.0467 - mse: 0.0467
# Epoch 10/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0344 - mse: 0.0343
# Epoch 11/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0305 - mse: 0.0304
# Epoch 12/20
# 546/546 [==============================] - 18s 32ms/step - loss: 0.0243 - mse: 0.0243
# Epoch 13/20
# 546/546 [==============================] - 17s 32ms/step - loss: 0.0298 - mse: 0.0297
# Epoch 14/20
# 546/546 [==============================] - 17s 30ms/step - loss: 0.0552 - mse: 0.0551
# Epoch 15/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0588 - mse: 0.0587
# Epoch 16/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0327 - mse: 0.0326
# Epoch 17/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0311 - mse: 0.0310
# Epoch 18/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0426 - mse: 0.0425
# Epoch 19/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0274 - mse: 0.0278
# Epoch 20/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.0291 - mse: 0.0290

# %%
pd.DataFrame(nn_reg_history.history).plot(figsize=(10, 5))
plt.grid(True)

# Set the xticks - label locations
plt.xticks(np.arange(0, 20, step=2))  

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 1)
# Out:
# (0, 1)

# %% [markdown]
# > <font color='red'>**Maximum Acceptable Loss Requirement**</font>: Your loss on `test_batch_reg` should not exceed **0.15**. Otherwise, your notebook will get NO CREDIT for this part, so you must fine-tune your `nn_reg` accordingly.

# %%
# Evaluate the model on test_batch_reg
loss, metric = nn_reg.evaluate(test_batch_reg)
# Out:
# 137/137 [==============================] - 0s 3ms/step - loss: 0.1548 - mse: 0.1554

# %%
# Maximum acceptable loss: 0.15
round(loss, 2)
# Out:
# 0.15

# %% [markdown]
# > Next, you're going to build another NN and use callback and early stopping to determine the optimal number of epochs.

# %%
# Build a sequential NN with appropriate layers for regression
# Use ReLU for all hidden layers

# Hint1: input_dim of the first layer should match with the number of features in X_train_reg
# Hint2: Notice that the activation function and number of neurons in the output layer are determined
# by the type of ML task i.e. Regression

nn_reg2 = tf.keras.Sequential([
    # Add layers accordingly
    tf.keras.layers.Dense(300, activation = 'relu', input_dim=1683),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),    
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(1)
    ])

# %%
# Create an optimizer of your choice with a learning rate of 0.001
#optimizer = None
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %% [markdown]
# > Next, you're going to create `callbacks` and `EarlyStopping`.
#
# > **Note:** The `patience` parameter is the number of epochs to monitor for improvement. You may want to look up textbook examples to learn how to do this, but notice that there is no validation data here.

# %%
# Create a tf.keras.callbacks with EarlyStopping method and monitor='loss' and patience=10 
early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=0)

# %%
# Compile nn_reg2 with appropriate loss, optimizer=optimizer and TWO metrics for regression
# Hint: The two metrics must be both for regression, and one of them may be the same as loss
nn_reg2.compile( loss= 'mean_squared_error',optimizer=optimizer, metrics=['mae', 'mse'])

# %% [markdown]
# > Now run the training, sit back and let tf/keras determine the optimal number of epochs!

# %%
EPOCHS = 1000
# Fit nn_reg2 on train_batch_reg, epochs=EPOCHS, callbacks=[early_stop]
nn_reg2_history = nn_reg2.fit(train_batch_reg, epochs=EPOCHS, callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 546/546 [==============================] - 4s 8ms/step - loss: 1.1034 - mae: 0.4023 - mse: 1.1034
# Epoch 2/1000
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5991 - mae: 0.3236 - mse: 0.5981
# Epoch 3/1000
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3133 - mae: 0.2631 - mse: 0.3131
# Epoch 4/1000
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2212 - mae: 0.2540 - mse: 0.2536
# Epoch 5/1000
# 546/546 [==============================] - 3s 5ms/step - loss: 1.1470 - mae: 0.2969 - mse: 1.1452

# %%
pd.DataFrame(nn_reg2_history.history).plot(figsize=(10, 5))
plt.grid(True)

# set the y-axis range to [0-1]
plt.gca().set_ylim(0, 6)
# Out:
# (0, 6)

# %% [markdown]
# ## Part II - Questions

# %% [markdown]
# ANSWER THE FOLLOWING QUESTIONS HERE:
#
# **Q1 [5 points]** <br>
# (a - 3 points) - Using eraly stopping and callbacks, how may epochs did the training run for `nn_reg2`? Find the attribute in history object that logs number of epochs. Write the code to get number of epochs in the following cell.
#
# (b - 2 points) - How did the training stop? Your answer should exactly mention the criteria for when the training stops. EXPLAIN CLEARLY AND COMPLETELY IN NO MORE THAN TWO SENTENCES! Training stopped after the validation error was consistently above the required minimum validation error and the model would not do better than the minimum.

# %%
# Get number of epochs from history object (Hint: it would return a list)
np.save('my_history.npy',nn_reg2_history.history)
print(len(nn_reg2_history.history['loss']))
# Out:
# 5

# %% [markdown]
# **Q2 [5 points]** - On the history plot of `nn_reg2`, you have three colors/curves, but only two of them are displayed. Explain why?
#
# At every epoch, the loss and mse are rounded to the same value, so the plot only needs to show the mae and mse since the rounded values of loss and mse are the same. Example:
# loss: 1.1, mse: 1.1
# loss: 0.5, mse: 0.5
# loss: 0.3, mse: 0.3
# loss: 0.2, mse: 0.2
# loss: 1.1, mse: 1.1

# %% [markdown]
# ## Grading
#
# Assignment-4 has a maximum of 100 points. Make sure that you get the correct outputs for all cells that you implement and give complete answers to all questions. Also, your notebook should be written with no grammatical and spelling errors and should be easy-to-read.
#
# The breakdown of the 100 points is as follows:
#
# - Part I Classification on Rating: [total 70 points]
#     - Implementation of nn_clf: 40 points - **Minimum Required Accuracy**: 0.70 otherwise ZERO CREDIT!
#     - Learning rate fine-tuning plot: 15 points
#     - Questions: 15 points (5 points each)
#
#
# - Part II Regression on NA_Sales: [total 30 points]
#     - Implementation of nn_reg: 10 points - **Maximum Acceptable Loss**: 0.15 otherwise ZERO CREDIT!
#     - Early stopping of nn_reg_2: 10 points
#     - Questions: 10 points (5 points each)
#
#
# <b>Note: </b>Follow the instructions of each section carefully. Up to 10 points may be deducted if your submitted notebook is not easy to read and follow or if it has grammatical, spelling or formatting issues.

# %% [markdown]
# Name your notebook ```Lastname-A4.ipynb```. Submit the completed notebook using the ```Assignment-4``` link on Blackboard.
#
# Grading will be based on
#
#   * correct implementation and results, correct answer to the questions, and
#   * readability of the notebook.
#
# <font color=red><b>Due Date: Monday May 4th, 11:59PM.</b></font>
